# %%
a = 5

# %%
b = 32

# %%
a + b
# Out:
# 37

# %%
str = "harry"

# %%
print("hello  world")
# Out:
# hello  world

# %%
#this is a comment

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type("name"))
# Out:
# <class 'str'>

# %%
type(str)
# Out:
# str

# %%
c="34234"

# %%
d="84884"

# %%
print(c+d)
# Out:
# 3423484884

# %%
int(c)+int(d)  #typecasting
# Out:
# 119118
