# %%
#A set in Python is an unordered, mutable, and unique collection of elements. It does not allow duplicate values.

# %%
a={}

# %%
type(a)
# Out:
# dict

# %%
b= set()

# %%
type(b)
# Out:
# set

# %%
s={4,2,4,5,3,4}

# %%
s
# Out:
# {2, 3, 4, 5}

# %%
unique_number =set([1,2,3,4,5,6])
print(unique_number) # {1,2,3,4,5,6}
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
s = {2,4,5,6,3,4}

# %%
s.add(34)

# %%
s
# Out:
# {2, 3, 4, 5, 6, 34}

# %%
s.update([344,344,121,435,766])

# %%
s
# Out:
# {2, 3, 4, 5, 6, 34, 121, 344, 435, 766}

# %%
s.pop()
# Out:
# 2

# %%
s.copy()
# Out:
# set()

# %%
s
# Out:
# set()

# %%
s1={1,2,3,4,5,67}
s2={3,4,5,6,7}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 67}

# %%
s1.intersection(s2)
# Out:
# {3, 4, 5}

# %%
s1.symmetric_difference(s2)
# Out:
# {1, 2, 6, 7, 67}

# %%
s1.issubset(s2)
# Out:
# False

# %%
s1.intersection(s2)
# Out:
# {3, 4, 5}

# %%
s1.issuperset(s2)
# Out:
# False
