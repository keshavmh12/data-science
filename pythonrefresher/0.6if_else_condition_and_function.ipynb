# %%
a=500

# %%
if(a>53):
    print("grater")
else:
    print("smaller")
# Out:
# smaller

# %%
x = 5
if x > 10:
    print("x is greater than 10")
elif x > 5:
    print("x is greater than 5 but not more than 10")
elif x == 5:
    print("x is exactly 5")
else:
    print("x is less than 5")
# Out:
# x is exactly 5

# %%
#function

# %%
def avg(a , b=10):  #B is default(fix) value
        return(a+b)/2

# %%
avg(4)
# Out:
# 7.0
