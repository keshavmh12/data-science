# %%
i=[1,2,3,4,5]

# %%
i[3]
# Out:
# 4

# %%
i.append(45)

# %%
i
# Out:
# [1, 2, 3, 4, 5, 45]

# %%
l=[65,67,56]

# %%
i.append(l)

# %%
i
# Out:
# [1, 2, 3, 4, 5, 45, [65, 67, 56]]

# %%
i.insert(1,66) # 1 is index no. 66 is element

# %%
i
# Out:
# [1, 66, 2, 3, 4, 5, 45, [65, 67, 56]]

# %%
num=i.pop(4)

# %%
num
# Out:
# 5

# %%
i.index(66)
# Out:
# 1

# %%
i.append(45)

# %%
i
# Out:
# [1, 66, 2, 3, 45, [65, 67, 56], 45]

# %%
i.count(45)
# Out:
# 2

# %%
sorted(l)
# Out:
# [56, 65, 67]

# %%
y=[1,2,True,False,[4,5]]  #nested_list

# %%
y[4]
# Out:
# [4, 5]

# %%
y[4][0]
# Out:
# 4

# %%
i+l+y
# Out:
# [1, 66, 2, 3, 45, [65, 67, 56], 45, 65, 67, 56, 1, 2, True, False, [4, 5]]

# %%
if 66 in i:
    print("YES")
else:
    print("NO")
# Out:
# YES

# %%
s="keshav-jill-kfkfdskn-kskfksf"

# %%
s.split("-")
# Out:
# ['keshav', 'jill', 'kfkfdskn', 'kskfksf']
