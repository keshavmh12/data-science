# %%
code=500

# %%
match code:
    case 200:
        print("response ok")
    case 400:
        print("bad response")
    case 404:
        print("not found")
    case _:
        print("Nothing matched")
print("end of program")
# Out:
# Nothing matched
# end of program
