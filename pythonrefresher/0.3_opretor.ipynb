# %%
#arithmatic optertor
a=10
b=4

# %%
a+b
# Out:
# 14

# %%
a-b
# Out:
# 6

# %%
a*b
# Out:
# 40

# %%
a/b
# Out:
# 2.5

# %%
2**2
# Out:
# 4

# %%
2**5
# Out:
# 32

# %%
a**b
# Out:
# 10000

# %%
a%b
# Out:
# 2

# %%
#comperision operator

# %%
a<b
# Out:
# False

# %%
a>b
# Out:
# True

# %%
a==b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
#logical operator

# %%
b1=True
b2=False

# %%
not(b1)
# Out:
# False

# %%
not(b2)
# Out:
# True

# %%
a!=b
# Out:
# True

# %%
#bitwise operator

# %%
a&b
# Out:
# 0

# %%
a|b
# Out:
# 14

# %%
#assignment operators

# %%
d=45

# %%
d+=6

# %%
d
# Out:
# 51

# %%
d-=4

# %%
d
# Out:
# 47

# %%
11//2
# Out:
# 5

# %%
a=11

# %%
a//=2

# %%
a
# Out:
# 5

# %%
#membership & identity operators
