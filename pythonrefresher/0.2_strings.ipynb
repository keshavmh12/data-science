# %%
name = "keshav"

# %%
name
# Out:
# 'keshav'

# %%
name.upper()
# Out:
# 'KESHAV'

# %%
name.endswith("av")
# Out:
# True

# %%
name.endswith("fdfv")
# Out:
# False

# %%
name.lower()
# Out:
# 'keshav'

# %%
name.count("a")
# Out:
# 1

# %%
print(len(name))
# Out:
# 6
