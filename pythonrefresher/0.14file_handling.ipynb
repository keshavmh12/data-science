# %%
#File handling allows Python programs to read, write, and manipulate files stored on disk. Python provides built-in functions for working with files.

# %%
f=open("text.txt","r")

# %%
f.read()
# Out:
# '\nher\ngood\ngoovvgh'

# %%
s="this is a nice way to learn data scinece"

# %%
f.close()

# %%
f=open("harry.txt","w")

# %%
f.write(s)
# Out:
# 40

# %%
f.close()

# %%
with open("harry.txt", "r") as file:
    content = file.read()
    print(content)  # No need to manually close the file
# Out:
# this is a nice way to learn data scinece
