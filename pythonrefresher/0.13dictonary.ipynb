# %%
#Empty dictonary

# %%
empty_dict = {}

# %%
# dictonary with key-value pairs

# %%
student = {
    "name":"keshav",
    "age":20,
    "grade":"A"
}

# %%
#using dict() constructor

# %%
person = dict(name="john",age=30,city="new york")

# %%
person
# Out:
# {'name': 'john', 'age': 30, 'city': 'new york'}

# %%
student
# Out:
# {'name': 'keshav', 'age': 20, 'grade': 'A'}

# %%
student["name"]
# Out:
# 'keshav'

# %%
student["age"]=67

# %%
print(student)
# Out:
# {'name': 'keshav', 'age': 67, 'grade': 'A'}

# %%
student.keys()
# Out:
# dict_keys(['name', 'age', 'grade'])

# %%
student.values()
# Out:
# dict_values(['keshav', 67, 'A'])

# %%
student.items()
# Out:
# dict_items([('name', 'keshav'), ('age', 67), ('grade', 'A')])

# %%
student.update({"name":"keshavaaa"})

# %%
student
# Out:
# {'name': 'keshavaaa', 'age': 67, 'grade': 'A'}

# %%
for key, value in student.items():
    print(key,":",value)
# Out:
# name : keshavaaa
# age : 67
# grade : A
